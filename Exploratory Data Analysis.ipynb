# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

# %%
data = pd.read_csv('H:\EXCEL\EDA4.csv')

# %%
data.head()
# Out:
#    Person_ID  AgeGroup_ID                         AgeGroupDesc  \
# 0        897            4             X Generation (1965-1980)
# 1       1864            4             X Generation (1965-1980)
# 2       2928            3  Baby Boomers Generation (1946-1964)
# 3       3204            4             X Generation (1965-1980)
# 4       3828            3  Baby Boomers Generation (1946-1964)
#
#    EmploymentTenure_ID EmploymentTenureDesc  Gender_ID GenderDesc  EEOCode_ID  \
# 0                  5.0     05). 90-120 days          2     Female           7
# 1                  4.0      04). 60-90 days          2     Female           0
# 2                  5.0     05). 90-120 days          2     Female           7
# 3                  2.0      02). 15-30 days          2     Female           6
# 4                  5.0     05). 90-120 days          2     Female           6
#
#                  EEOCodeDesc  Salary_ID  ... TMSurvey_NumberOfHoursAnswer  \
# ...

# %%
data.describe()
# Out:
#           Person_ID   AgeGroup_ID  EmploymentTenure_ID     Gender_ID  \
# count  2.344000e+04  23440.000000         23398.000000  23440.000000
# mean   1.015980e+07      5.583276             3.217796      1.553072
# std    9.005834e+05      0.682169             1.459284      0.497186
# min    8.970000e+02      2.000000             1.000000      1.000000
# 25%    1.023454e+07      5.000000             2.000000      1.000000
# 50%    1.024754e+07      6.000000             3.000000      2.000000
# 75%    1.025474e+07      6.000000             5.000000      2.000000
# max    1.026370e+07      6.000000            17.000000      2.000000
#
#          EEOCode_ID     Salary_ID     Status_ID       PTFT_ID  PayStatus_ID  \
# count  23440.000000  23440.000000  23440.000000  23440.000000       23440.0
# mean       6.955375      2.494539      1.685836      1.009642           1.0
# std        1.798968      0.499981      0.464192      0.097719           0.0
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# Person_ID
# AgeGroup_ID
# AgeGroupDesc
# EmploymentTenure_ID
# EmploymentTenureDesc
# Gender_ID
# GenderDesc
# EEOCode_ID
# EEOCodeDesc
# Salary_ID
# SalaryDesc
# Status_ID
# StatusDesc
# PTFT_ID
# PTFTDesc
# PayStatus_ID
# PayStatusDesc
# NumberOfWeeks
# RegularHours
# OvertimeHours
# PTOHours
# VacationHours
# YearsTenure
# CallOffs
# HoursSunday6AM2PM
# HoursSunday2PM10PM
# HoursSunday10PM6AM
# HoursMonday6AM2PM
# HoursMonday2PM10PM
# HoursMonday10PM6AM
# HoursTuesday6AM2PM
# HoursTuesday2PM10PM
# HoursTuesday10PM6AM
# HoursWednesday6AM2PM
# HoursWednesday2PM10PM
# HoursWednesday10PM6AM
# HoursThursday6AM2PM
# HoursThursday2PM10PM
# HoursThursday10PM6AM
# HoursFriday6AM2PM
# HoursFriday2PM10PM
# HoursFriday10PM6AM
# HoursSaturday6AM2PM
# HoursSaturday2PM10PM
# HoursSaturday10PM6AM
# WorkDayGroup_ID
# WorkDayGroupDesc
# WorkShiftGroup_ID
# WorkShiftGroupDesc
# HoursWorkedDown2Bodies
# HoursWorkedWithGM
# TMSurvey_Participated
# TMSurvey_ParticipatedDesc
# TMSurvey_OverallSentiment
# ...

# %%
# To see if there are any null values
data.isnull().sum()
# Out:
# Person_ID                    0
# AgeGroup_ID                  0
# AgeGroupDesc                 0
# EmploymentTenure_ID         42
# EmploymentTenureDesc        42
#                             ..
# DaysOfWork                   0
# WeeksWorked                  0
# HoursPerWeek                 0
# RegularHoursWeekGroup_ID     0
# RegularHoursWeekGroup        0
# Length: 71, dtype: int64

# %%
data.shape
# Out:
# (23440, 71)

# %%
df = data[['Status_ID','Age','Gender_ID','RegularHours','OvertimeHours','PTOHours','CallOffs','VacationHours','HoursPerWeek','YearsTenure','RegularHoursWeekGroup_ID']]

# %%
corelation = df.corr()
sns.heatmap(corelation, xticklabels=corelation.columns,yticklabels=corelation.columns,
           annot=True)
# The more regular hours they wok - the more they are likely to leave 
# The less hours per week they work - the more they are likely to leave
# The more irregular (overnight) hours they work - the more they are likely to leave
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.displot(df['RegularHoursWeekGroup_ID'])
# See how 'RegularHoursWeekGroup_ID' are distributed

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
fig = df.hist(bins=15,color='fuchsia',edgecolor='darkmagenta',linewidth=1.0,
              xlabelsize=10,ylabelsize=10,xrot=45,yrot=0,figsize=(10,9),grid=False)

plt.tight_layout(rect=(0,0,1.5,1.5))

# %%
# Multivariable analysis on the combined dataframe
# fig,(ax) = plt.subplots(1,1,figsize=(14,8))

# %%
#fig = plt.figure(figsize=(16,12))
# ax = fig.add_subplot(111,projection='3d')

# %%
df1 = df[['Status_ID','HoursPerWeek']]
df1
# Out:
#        Status_ID  HoursPerWeek
# 0              1     28.886534
# 1              1     34.525141
# 2              1     15.730898
# 3              2     10.589788
# 4              1     19.848700
# ...          ...           ...
# 23435          1    109.762557
# 23436          1    253.022832
# 23437          2      0.453300
# 23438          1     77.543379
# 23439          2      1.787049
#
# [23440 rows x 2 columns]

# %%
# Distribution of Hours Worked per Week in 5 hours intervals
plt.hist(df['HoursPerWeek'], bins=[0,5,10,15,20,25,30,35,40,45,50])
plt.show()

# %%
df['HoursPerWeek'].describe()
# Out:
# count    23440.000000
# mean        15.089950
# std         11.319619
# min        -10.995434
# 25%          7.074938
# 50%         13.642146
# 75%         21.226088
# max        253.022832
# Name: HoursPerWeek, dtype: float64

# %%
# Finding correlation coefficient bwtween hours worked and a Status ID
df['HoursPerWeek'].corr(df['Status_ID'])
# Out:
# -0.4535640011100351

# %%
# Hours worked and hours worked group by Status_ID
sns.relplot(x = 'HoursPerWeek', y = 'Status_ID', hue = 'Status_ID', data = df)
# Status ID: 1 = Active, 2 = Terminated

# %%
# Descrete categorical attributes
fig = plt.figure(figsize=(16,8))
sns.countplot(data=data,x="RegularHoursWeekGroup_ID",hue="Status_ID")
# Status_ID: 1=Active, 2=Terminated

# Used SQL grouping. 

# RegularHoursWeekGroup_ID Description:
# Group1: less than 7 h/week
# Group2: between 7 and 12 h/week
# Group3: between 12 and 18 h/week
# Group4: between 18 and 25 h/week
# Group5: 25+ h/week

#Conclusion: people who work 7 or less than 7 hours/week are extremily likely to leave
# Out:
# <AxesSubplot:xlabel='RegularHoursWeekGroup_ID', ylabel='count'>

# %%
'''

colors_list = ['#5cb85c','#d9534f']

# Normalize results
result_pct = result.div(result.sum(),axis = 0)
ax = df.plot(kind='bar',figsize = (15,4), width = 0.8, color = colors_list, edgecolor = None)
plt.legend(labels = result.columns, fontsize = 14)
plt.title("Percentage of employment status", fontsize = 16)

plt.xticks(size = 14)
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.yticks([])

# Loop to add the annotations
for p in ax.patches:
    width = p.get_width()
    height = p.get_heaight()
    x,y = p.get_xy()
    ax.annotate(f'{height:0.0%}', (x+ width/2, y+ height*1.02), ha='center')
    
'''
# Out:
# '\n\ncolors_list = [\'#5cb85c\',\'#d9534f\']\n\n# Normalize results\nresult_pct = result.div(result.sum(),axis = 0)\nax = df.plot(kind=\'bar\',figsize = (15,4), width = 0.8, color = colors_list, edgecolor = None)\nplt.legend(labels = result.columns, fontsize = 14)\nplt.title("Percentage of employment status", fontsize = 16)\n\nplt.xticks(size = 14)\nfor spine in plt.gca().spines.values():\n    spine.set_visible(False)\nplt.yticks([])\n\n# Loop to add the annotations\nfor p in ax.patches:\n    width = p.get_width()\n    height = p.get_heaight()\n    x,y = p.get_xy()\n    ax.annotate(f\'{height:0.0%}\', (x+ width/2, y+ height*1.02), ha=\'center\')\n    \n'

# %%
def with_hue(plot, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in plot.patches]
    patch = [p for p in plot.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 12)
    plt.show()

# %%
#Determine the percentage of employees who left in particular Hour Group

# Descrete categorical attributes
plt.figure(figsize=(16,8))
ax = sns.countplot(x="RegularHoursWeekGroup_ID",hue="Status_ID",data = df)

plt.xticks(size = 12)
plt.xlabel('RegularHoursWeekGroup_ID',size = 12)
plt.yticks(size = 12)
plt.ylabel('Count', size =12)

# Function call
with_hue(ax, df['RegularHoursWeekGroup_ID'],5,2)

# Why are percentages more than 100???

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,precision_score, recall_score,f1_score

# %%
# Encoding: split the set into 1,2,3 values

#label_quality = LabelEncoder()
#df['RegularHoursWeekGroup_ID'] = label_quality.fit_transform(df['RegularHoursWeekGroup_ID'])

# %%
# Split the dataset into training/test sets
x_train, x_test, y_train, y_test = train_test_split(df.drop(['RegularHoursWeekGroup_ID','Status_ID'],axis = 1),df['RegularHoursWeekGroup_ID'],test_size = 0.30,random_state = 7)

# %%
# Build models indivitially for every algorithm
# Create models
models=[LogisticRegression(),
       LinearSVC(),
       KNeighborsClassifier(),
       RandomForestClassifier(),
       DecisionTreeClassifier(),
       GradientBoostingClassifier(),
       GaussianNB()]

model_names = ['LogisticRegression','LinearSVC','KNeighborsClassifier','RandomForestClassifier','DecisionTreeClassifier','GradientBoostingClassifier','GaussianNB']

# %%
# Loop over each model and evaluate the accuracy of each model

acc=[]
eval_acc={}

for model in range(len(models)):
    classification_model = models[model]
    classification_model.fit(x_train,y_train)
    pred = classification_model.predict(x_test)
    acc.append(accuracy_score(pred,y_test))
eval_acc = {'ModellingAlgorithm': model_names,'Accuracy':acc}
eval_acc
# Out:
# C:\Users\holovcha\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\holovcha\Anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# {'ModellingAlgorithm': ['LogisticRegression',
#   'LinearSVC',
#   'KNeighborsClassifier',
#   'RandomForestClassifier',
#   'DecisionTreeClassifier',
#   'GradientBoostingClassifier',
#   'GaussianNB'],
#  'Accuracy': [0.5827645051194539,
#   0.6648179749715586,
#   0.891353811149033,
# ...

# %%
# Create the dataframe of the accuracy of the model and show it in chart

pd.DataFrame(eval_acc['ModellingAlgorithm'],eval_acc['Accuracy'])
#acc_table = acc_table.soft_values(by='Accuracy',ascending=[False])
#acc_table
# Out:
#                                    0
# 0.582765          LogisticRegression
# 0.664818                   LinearSVC
# 0.891354        KNeighborsClassifier
# 0.999716      RandomForestClassifier
# 0.999858      DecisionTreeClassifier
# 0.999858  GradientBoostingClassifier
# 0.890643                  GaussianNB
